# %%
from plyfile import PlyData, PlyElement
import pcl
from pcl import pcl_visualization
import numpy as np

# %%
#load ply file generated by pyrealsense library
loadedPlyFile = pcl.load("./out.ply")

# binary ply to ascii ply
pcl.save(loadedPlyFile, "./pcl.ply")

# binary ply to ascii pcd
pcl.save(loadedPlyFile, "./pcl.pcd")

# %%
# load plyfile (binary or ascii format)
# plydata = PlyData.read('./out.ply') #binary
plydata = PlyData.read('./pcl.ply') #ascii

# %%
# get nparray of (index) of ply file
plydata.elements[0].data #returns all data of element index 0
plydata.elements[0].data[211702] #returns index 1 of data of element index 0
# x, y, z
# Out:
# (0.30141434, -0.47647873, -1.217)
